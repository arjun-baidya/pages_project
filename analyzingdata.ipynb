# %% [markdown]
# # Analyzing the data Set
#
# import pandas as pd
# import numpy as np
# customers=pd.read_csv("customersdata.csv")
# customers

# %%
customers.shape
customers.head()
# Out:
#   fraudulent customer__customerEmail customer__customerPhone  \
# 0      False  josephhoward@yahoo.com            400-108-5415
# 1        NaN                     NaN                     NaN
# 2       True  evansjeffery@yahoo.com          1-788-091-7546
# 3        NaN                     NaN                     NaN
# 4        NaN                     NaN                     NaN
#
#   customer__customerDevice customer__customerIPAddress  \
# 0     yyeiaxpltf82440jnb3v                8.129.104.40
# 1                      NaN                         NaN
# 2     r0jpm7xaeqqa3kr6mzum             219.173.211.202
# 3                      NaN                         NaN
# 4                      NaN                         NaN
#
#                     customer__customerBillingAddress orders__orderId  \
# 0            5493 Jones Islands\nBrownside, CA 51896          vjbdvd
# 1                                                NaN          yp6x27
# ...

# %%
customers.head(15)
# Out:
#    fraudulent    customer__customerEmail customer__customerPhone  \
# 0       False     josephhoward@yahoo.com            400-108-5415
# 1         NaN                        NaN                     NaN
# 2        True     evansjeffery@yahoo.com          1-788-091-7546
# 3         NaN                        NaN                     NaN
# 4         NaN                        NaN                     NaN
# 5         NaN                        NaN                     NaN
# 6         NaN                        NaN                     NaN
# 7         NaN                        NaN                     NaN
# 8         NaN                        NaN                     NaN
# 9       False  andersonwilliam@yahoo.com            024.420.0375
# 10        NaN                        NaN                     NaN
# 11        NaN                        NaN                     NaN
# 12        NaN                        NaN                     NaN
# ...

# %%
customers.tail()
# Out:
#     fraudulent customer__customerEmail customer__customerPhone  \
# 701        NaN                     NaN                     NaN
# 702        NaN                     NaN                     NaN
# 703        NaN                     NaN                     NaN
# 704        NaN                     NaN                     NaN
# 705        NaN                     NaN                     NaN
#
#     customer__customerDevice customer__customerIPAddress  \
# 701                      NaN                         NaN
# 702                      NaN                         NaN
# 703                      NaN                         NaN
# 704                      NaN                         NaN
# 705                      NaN                         NaN
#
#     customer__customerBillingAddress orders__orderId  orders__orderAmount  \
# 701                              NaN          1bubxa                 25.0
# 702                              NaN          p0gdbf                 19.0
# ...

# %%
customers.tail(12)
# Out:
#     fraudulent  customer__customerEmail customer__customerPhone  \
# 694        NaN                      NaN                     NaN
# 695        NaN                      NaN                     NaN
# 696        NaN                      NaN                     NaN
# 697        NaN                      NaN                     NaN
# 698        NaN                      NaN                     NaN
# 699      False  dawn05@tucker-brown.com      (089)703-7360x8848
# 700        NaN                      NaN                     NaN
# 701        NaN                      NaN                     NaN
# 702        NaN                      NaN                     NaN
# 703        NaN                      NaN                     NaN
# 704        NaN                      NaN                     NaN
# 705        NaN                      NaN                     NaN
#
#     customer__customerDevice customer__customerIPAddress  \
# 694                      NaN                         NaN
# ...

# %%
customers.shape
# Out:
# (706, 20)

# %%
customers.info(null_counts=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 706 entries, 0 to 705
# Data columns (total 20 columns):
# fraudulent                                          object
# customer__customerEmail                             object
# customer__customerPhone                             object
# customer__customerDevice                            object
# customer__customerIPAddress                         object
# customer__customerBillingAddress                    object
# orders__orderId                                     object
# orders__orderAmount                                 float64
# orders__orderState                                  object
# orders__orderShippingAddress                        object
# paymentMethods__paymentMethodId                     object
# paymentMethods__paymentMethodRegistrationFailure    object
# paymentMethods__paymentMethodType                   object
# paymentMethods__paymentMethodProvider               object
# ...

# %%
customers.mean()
# Out:
# fraudulent                                           0.363095
# orders__orderAmount                                 35.606695
# paymentMethods__paymentMethodRegistrationFailure     0.116959
# transactions__transactionAmount                     34.598716
# transactions__transactionFailed                      0.269663
# dtype: float64

# %%
customers.median()
# Out:
# fraudulent                                           0.0
# orders__orderAmount                                 35.0
# paymentMethods__paymentMethodRegistrationFailure     0.0
# transactions__transactionAmount                     34.0
# transactions__transactionFailed                      0.0
# dtype: float64

# %%
customers.std()
# Out:
# fraudulent                                           0.482330
# orders__orderAmount                                 21.667298
# paymentMethods__paymentMethodRegistrationFailure     0.321842
# transactions__transactionAmount                     20.360247
# transactions__transactionFailed                      0.444141
# dtype: float64

# %%
customers.max()
# Out:
# fraudulent                                          True
# orders__orderAmount                                  353
# paymentMethods__paymentMethodRegistrationFailure    True
# transactions__transactionAmount                      353
# transactions__transactionFailed                     True
# dtype: object

# %%
customers.min()
# Out:
# fraudulent                                          False
# orders__orderAmount                                    10
# paymentMethods__paymentMethodRegistrationFailure    False
# transactions__transactionAmount                        10
# transactions__transactionFailed                     False
# dtype: object

# %%
customers.count()
# Out:
# fraudulent                                          168
# customer__customerEmail                             168
# customer__customerPhone                             168
# customer__customerDevice                            168
# customer__customerIPAddress                         168
# customer__customerBillingAddress                    168
# orders__orderId                                     478
# orders__orderAmount                                 478
# orders__orderState                                  478
# orders__orderShippingAddress                        478
# paymentMethods__paymentMethodId                     342
# paymentMethods__paymentMethodRegistrationFailure    342
# paymentMethods__paymentMethodType                   342
# paymentMethods__paymentMethodProvider               342
# paymentMethods__paymentMethodIssuer                 342
# transactions__transactionId                         623
# transactions__orderId                               623
# ...

# %%
customers.describe()
# Out:
#        orders__orderAmount  transactions__transactionAmount
# count           478.000000                       623.000000
# mean             35.606695                        34.598716
# std              21.667298                        20.360247
# min              10.000000                        10.000000
# 25%              22.000000                        21.000000
# 50%              35.000000                        34.000000
# 75%              46.000000                        45.000000
# max             353.000000                       353.000000

# %%
customers
# Out:
#     fraudulent          customer__customerEmail customer__customerPhone  \
# 0        False           josephhoward@yahoo.com            400-108-5415
# 1          NaN                              NaN                     NaN
# 2         True           evansjeffery@yahoo.com          1-788-091-7546
# 3          NaN                              NaN                     NaN
# 4          NaN                              NaN                     NaN
# 5          NaN                              NaN                     NaN
# 6          NaN                              NaN                     NaN
# 7          NaN                              NaN                     NaN
# 8          NaN                              NaN                     NaN
# 9        False        andersonwilliam@yahoo.com            024.420.0375
# 10         NaN                              NaN                     NaN
# 11         NaN                              NaN                     NaN
# ...

# %%
customers.fraudulent=customers.fraudulent.astype(float)

# %%
# view specific column

customers.iloc[:,4]
# Out:
# 0                                 8.129.104.40
# 1                                          NaN
# 2                              219.173.211.202
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9      67b7:3db8:67e0:3bea:b9d0:90c1:2b60:b9f0
# 10                                         NaN
# 11                                         NaN
# 12                                         NaN
# 13                                         NaN
# 14     95de:8565:5a66:792c:26e0:6cfb:7d87:11af
# 15                                         NaN
# 16                                         NaN
# 17                              196.89.235.192
# 18                                         NaN
# 19                                         NaN
# ...

# %%
# To view among columns data

customers.loc[:8,"fraudulent":"customer__customerIPAddress"]
# Out:
#    fraudulent customer__customerEmail customer__customerPhone  \
# 0         1.0  josephhoward@yahoo.com            400-108-5415
# 1         1.0                     NaN                     NaN
# 2         1.0  evansjeffery@yahoo.com          1-788-091-7546
# 3         1.0                     NaN                     NaN
# 4         1.0                     NaN                     NaN
# 5         1.0                     NaN                     NaN
# 6         1.0                     NaN                     NaN
# 7         1.0                     NaN                     NaN
# 8         1.0                     NaN                     NaN
#
#    customer__customerDevice customer__customerIPAddress
# 0                       1.0                8.129.104.40
# 1                       1.0                         NaN
# 2                       1.0             219.173.211.202
# 3                       1.0                         NaN
# 4                       1.0                         NaN
# ...

# %%
# Sorting

customers.sort_values(by='orders__orderAmount')
# Out:
#      fraudulent            customer__customerEmail customer__customerPhone  \
# 53          1.0     christineklein@wright-boyd.org        897-464-6425x941
# 644         1.0             martinezlori@gmail.com      353.413.2223x82475
# 169         1.0  jamescampbell@randall-pacheco.biz            599-142-6783
# 115         1.0                                NaN                     NaN
# 149         1.0                   mark02@young.com           (833)029-3127
# 310         1.0                                NaN                     NaN
# 432         1.0                                NaN                     NaN
# 467         1.0                                NaN                     NaN
# 380         1.0     watkinscaroline@lewis-haas.com       153-392-3908x8124
# 324         1.0                                NaN                     NaN
# 627         1.0                                NaN                     NaN
# ...

# %%
customers.sort_values(by='orders__orderAmount',ascending=False)
# Out:
#      fraudulent        customer__customerEmail customer__customerPhone  \
# 206         1.0              uguzman@yahoo.com           (017)893-9493
# 124         1.0                            NaN                     NaN
# 346         1.0                            NaN                     NaN
# 31          1.0                            NaN                     NaN
# 480         1.0              ugood@mosley.info            869-856-7969
# 418         1.0              david45@gmail.com           (508)223-3834
# 501         1.0  amywright@wallace-johnson.com            629.489.3980
# 606         1.0                            NaN                     NaN
# 357         1.0                            NaN                     NaN
# 445         1.0          tmcpherson@wright.com    1-804-264-1481x08539
# 313         1.0                            NaN                     NaN
# 461         1.0                            NaN                     NaN
# ...
